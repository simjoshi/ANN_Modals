# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import seaborn as sns

# %% [markdown]
# Data 1

# %%
data1 = random.sample(range(1, 1000), 10)

# appending 1500 as it is the clear outlier
data1.append(1600)
data1
# Out:
# [198, 490, 412, 736, 350, 220, 623, 728, 727, 521, 1600]

# %%
sns.boxplot(data1)
# Out:
# <Axes: >

# %% [markdown]
# Data 2

# %%
data2 = random.sample(range(1,100), 20)
data2.append(170)
data2
# Out:
# [95,
#  43,
#  6,
#  69,
#  85,
#  38,
#  28,
#  75,
#  47,
#  3,
#  88,
#  45,
#  64,
#  27,
#  57,
#  30,
#  60,
#  82,
#  19,
#  14,
#  170]

# %%
sns.boxplot(data2)
# Out:
# <Axes: >

# %% [markdown]
# Data 3

# %%
data3 = random.sample(range(300, 500), 15)
data3.append(1)
data3
# Out:
# [308, 389, 445, 407, 488, 495, 453, 467, 408, 353, 382, 442, 341, 465, 486, 1]

# %%
sns.boxplot(data3)
# Out:
# <Axes: >

# %% [markdown]
# Data 4

# %%
data4 = random.sample(range(1, 50), 10)
data4.append(100)
data4
# Out:
# [47, 13, 20, 48, 45, 3, 22, 2, 29, 9, 100]

# %%
sns.boxplot(data3, color='green')
# Out:
# <Axes: >

# %% [markdown]
# Data 5

# %%
data5 = random.sample(range(50, 3300), 35)
data5.append(10000)
data5
# Out:
# [276,
#  852,
#  1929,
#  1059,
#  2685,
#  2917,
#  819,
#  3139,
#  3095,
#  460,
#  1336,
#  2570,
#  1612,
#  725,
#  2269,
#  1719,
#  2354,
#  1963,
#  1656,
#  3183,
#  2098,
#  2439,
#  2200,
#  1434,
#  1361,
#  1800,
#  2013,
#  2484,
#  54,
#  1368,
#  2141,
#  2366,
#  1159,
#  3260,
#  169,
#  10000]

# %%
sns.boxplot(x=data5, color='red')
# Out:
# <Axes: >

# %% [markdown]
# Data 6

# %%
data6 = random.sample(range(1, 1000), 500)
data6.extend(random.sample(range(2000, 2500), 10))
data6
# Out:
# [267,
#  72,
#  574,
#  637,
#  830,
#  49,
#  473,
#  675,
#  302,
#  410,
#  273,
#  36,
#  182,
#  23,
#  417,
#  531,
#  371,
#  429,
#  703,
#  91,
#  404,
#  326,
#  198,
#  430,
#  899,
#  459,
#  729,
#  82,
#  413,
#  594,
#  593,
#  535,
#  456,
#  53,
#  454,
#  304,
#  210,
#  735,
#  525,
#  348,
#  894,
#  63,
#  777,
#  480,
#  586,
#  765,
#  287,
#  825,
#  245,
#  720,
#  233,
#  633,
#  839,
#  713,
#  169,
#  167,
#  408,
#  997,
#  315,
#  937,
#  695,
#  472,
#  462,
#  93,
#  425,
#  893,
#  385,
#  146,
#  873,
#  671,
#  812,
#  567,
#  131,
#  333,
#  852,
#  704,
#  592,
#  352,
#  243,
#  514,
#  235,
#  34,
#  710,
#  669,
#  742,
#  865,
#  197,
#  476,
#  632,
#  374,
#  229,
#  609,
#  106,
#  623,
#  58,
#  847,
#  193,
#  168,
#  639,
#  583,
#  184,
#  320,
#  923,
#  790,
#  359,
#  224,
#  366,
#  792,
#  369,
#  295,
#  128,
#  738,
#  920,
#  809,
#  478,
#  171,
#  461,
#  42,
#  672,
#  974,
#  217,
#  78,
#  223,
#  249,
#  142,
#  783,
# ...

# %%
sns.boxplot(x=data6, color='purple', width=0.8)
# Out:
# <Axes: >

# %% [markdown]
# Data 7

# %%
data7 = random.sample(range(1, 100), 20)
data7.extend(random.sample(range(190, 250), 5))
data7
# Out:
# [13,
#  8,
#  20,
#  38,
#  90,
#  10,
#  99,
#  85,
#  91,
#  98,
#  64,
#  30,
#  71,
#  51,
#  50,
#  79,
#  70,
#  81,
#  19,
#  5,
#  200,
#  193,
#  243,
#  211,
#  232]

# %%
sns.boxplot(y=data6, color='yellow')
# Out:
# <Axes: >

# %% [markdown]
# Data 8

# %%
data8 = random.sample(range(100, 1000), 50)
data8.extend(random.sample(range(2000, 2800), 10))
data8
# Out:
# [771,
#  420,
#  455,
#  247,
#  133,
#  704,
#  911,
#  774,
#  310,
#  224,
#  140,
#  401,
#  634,
#  334,
#  876,
#  489,
#  741,
#  960,
#  145,
#  269,
#  177,
#  994,
#  424,
#  909,
#  841,
#  396,
#  691,
#  474,
#  469,
#  638,
#  432,
#  434,
#  311,
#  632,
#  685,
#  369,
#  288,
#  344,
#  305,
#  399,
#  813,
#  138,
#  635,
#  657,
#  858,
#  784,
#  286,
#  500,
#  795,
#  762,
#  2443,
#  2054,
#  2031,
#  2337,
#  2765,
#  2233,
#  2073,
#  2787,
#  2335,
#  2349]

# %%
sns.boxplot(x=data8, color='pink', width=0.9)
# Out:
# <Axes: >

# %% [markdown]
# Data 9

# %%
data9 = random.sample(range(50, 800), 100)
data9.extend(random.sample(range(1500, 3500), 10))
data9
# Out:
# [165,
#  715,
#  68,
#  477,
#  300,
#  755,
#  397,
#  536,
#  322,
#  220,
#  232,
#  353,
#  450,
#  554,
#  514,
#  655,
#  350,
#  592,
#  587,
#  162,
#  756,
#  407,
#  58,
#  475,
#  526,
#  231,
#  710,
#  205,
#  301,
#  733,
#  682,
#  416,
#  571,
#  95,
#  313,
#  739,
#  362,
#  465,
#  274,
#  64,
#  330,
#  617,
#  455,
#  457,
#  773,
#  456,
#  171,
#  443,
#  143,
#  711,
#  204,
#  83,
#  145,
#  686,
#  738,
#  277,
#  607,
#  261,
#  602,
#  741,
#  652,
#  159,
#  393,
#  290,
#  248,
#  124,
#  673,
#  368,
#  557,
#  772,
#  438,
#  797,
#  302,
#  549,
#  437,
#  190,
#  743,
#  633,
#  698,
#  641,
#  96,
#  776,
#  528,
#  629,
#  413,
#  310,
#  151,
#  174,
#  351,
#  494,
#  572,
#  241,
#  747,
#  469,
#  786,
#  314,
#  342,
#  76,
#  240,
#  269,
#  2643,
#  3164,
#  3469,
#  1832,
#  2841,
#  2760,
#  3485,
#  2683,
#  2768,
#  2625]

# %%
sns.boxplot(data9)
# Out:
# <Axes: >

# %% [markdown]
# Data 10

# %%
data10 = random.sample(range(1000, 2000), 250)
data10.extend(random.sample(range(3000, 4500), 10))
data10
# Out:
# [1056,
#  1158,
#  1294,
#  1219,
#  1530,
#  1649,
#  1702,
#  1460,
#  1958,
#  1611,
#  1744,
#  1586,
#  1160,
#  1166,
#  1626,
#  1942,
#  1719,
#  1414,
#  1319,
#  1067,
#  1846,
#  1623,
#  1887,
#  1812,
#  1575,
#  1498,
#  1860,
#  1935,
#  1223,
#  1993,
#  1855,
#  1761,
#  1281,
#  1234,
#  1428,
#  1890,
#  1661,
#  1898,
#  1145,
#  1048,
#  1293,
#  1398,
#  1345,
#  1679,
#  1313,
#  1357,
#  1353,
#  1971,
#  1228,
#  1202,
#  1727,
#  1539,
#  1588,
#  1754,
#  1897,
#  1796,
#  1358,
#  1110,
#  1459,
#  1045,
#  1858,
#  1403,
#  1070,
#  1637,
#  1911,
#  1545,
#  1468,
#  1256,
#  1533,
#  1187,
#  1631,
#  1894,
#  1544,
#  1614,
#  1598,
#  1959,
#  1907,
#  1764,
#  1461,
#  1802,
#  1425,
#  1642,
#  1918,
#  1565,
#  1298,
#  1692,
#  1204,
#  1571,
#  1426,
#  1165,
#  1270,
#  1616,
#  1068,
#  1504,
#  1231,
#  1583,
#  1020,
#  1967,
#  1224,
#  1478,
#  1965,
#  1112,
#  1152,
#  1779,
#  1577,
#  1992,
#  1709,
#  1328,
#  1151,
#  1390,
#  1885,
# ...

# %%
sns.boxplot(data10, color='orange')
# Out:
# <Axes: >

# %% [markdown]
# Data set of all 10 datas

# %%
dataset = [data1, data2, data3, data4, data5, data6, data7, data8, data9, data10]
fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
 
# Creating plot
bp = ax.boxplot(dataset)
 
# show plot
plt.show()
